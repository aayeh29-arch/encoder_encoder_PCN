# %%
# !pip uninstall tensorflow
# Out:
# ^C

# %%
import sys; print(sys.executable)
# Out:
# c:\Users\user\miniconda3\envs\tf_py3.10\python.exe

# %%
import tensorflow as tf
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.transpose
# Out:
# <function tensorflow.python.ops.array_ops.transpose_v2(a, perm=None, conjugate=False, name='transpose')>

# %%
tf.sqrt
# Out:
# <function tensorflow.python.ops.math_ops.sqrt(x, name=None)>

# %%
tf.sqrt(2.)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tf.sqrt(2.)
#
# File c:\Users\user\miniconda3\envs\tf_py3.10\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\user\miniconda3\envs\tf_py3.10\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\user\miniconda3\envs\tf_py3.10\lib\site-packages\tensorflow\python\ops\math_ops.py:5415, in sqrt(x, name)
#    5380 @tf_export("math.sqrt", "sqrt")
#    5381 @dispatch.register_unary_elementwise_api
#    5382 @dispatch.add_dispatch_support
#    5383 def sqrt(x, name=None):  # pylint: disable=redefined-builtin
#    5384   r"""Computes element-wise square root of the input tensor.
#    5385
#    5386   Note: This operation does not support integer types.
#    (...)
#    5413     A `tf.Tensor` of same size, type and sparsity as `x`.
#    5414   """
# -> 5415   return gen_math_ops.sqrt(x, name)
#
# File c:\Users\user\miniconda3\envs\tf_py3.10\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:10804, in sqrt(x, name)
#   10802   pass
#   10803 try:
# > 10804   return sqrt_eager_fallback(
#   10805       x, name=name, ctx=_ctx)
#   10806 except _core._SymbolicException:
#   10807   pass  # Add nodes to the TensorFlow graph.
#
# File c:\Users\user\miniconda3\envs\tf_py3.10\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:10827, in sqrt_eager_fallback(x, name, ctx)
#   10825 _inputs_flat = [x]
#   10826 _attrs = ("T", _attr_T)
# > 10827 _result = _execute.execute(b"Sqrt", 1, inputs=_inputs_flat, attrs=_attrs,
#   10828                            ctx=ctx, name=name)
#   10829 if _execute.must_record_gradient():
#   10830   _execute.record_gradient(
#   10831       "Sqrt", _inputs_flat, _attrs, _result)
#
# File c:\Users\user\miniconda3\envs\tf_py3.10\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
tf.constant([1., 2., 3.])
